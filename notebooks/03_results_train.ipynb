# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
project_root = os.path.dirname(os.getcwd())
models_path = os.path.join(project_root,'models')

results_path = models_path +'/results'

# %%
df_cv_temp = pd.read_csv(results_path+ '/resultados_cv_temporales.csv')
df_cv_spec = pd.read_csv(results_path+ '/resultados_cv_espectrales.csv')

# %%
df_cv_temp
# Out:
#          Modelo  F1-score  Balanced accuracy  Accuracy
# 0  RandomForest  0.966538           0.950601  0.966924
# 1           KNN  0.986349           0.974795  0.986376
# 2           SVM  0.216126           0.166667  0.387074
# 3           MLP  0.855362           0.772316  0.863471
# 4          LSTM  0.885274           0.837320  0.890791
# 5           CNN  0.914409           0.871522  0.913961

# %%
df_cv_spec
# Out:
#          Modelo  F1-score  Balanced accuracy  Accuracy
# 0  RandomForest  0.924271           0.886725  0.927655
# 1           KNN  0.920455           0.886171  0.922119
# 2           SVM  0.686714           0.615297  0.758050
# 3           MLP  0.830577           0.750058  0.847369
# 4          LSTM  0.536744           0.425617  0.595949
# 5           CNN  0.913262           0.902606  0.909153

# %%
df_test_temp = pd.read_csv(results_path+ '/resultados_test_temporales.csv')
df_test_spec = pd.read_csv(results_path+ '/resultados_test_espectrales.csv')

# %%
df_test_temp
# Out:
#          Modelo  F1-score  Balanced accuracy  Accuracy  \
# 0  RandomForest  0.968898           0.950009  0.969406
# 1           KNN  0.985633           0.968198  0.985723
# 2           SVM  0.211171           0.166667  0.381993
# 3           MLP  0.892514           0.831687  0.896853
# 4          LSTM  0.892671           0.837389  0.899767
# 5           CNN  0.873911           0.836078  0.869755
#
#                                 Archivo
# 0  randomforest_features_temporales.pkl
# 1           knn_features_temporales.pkl
# 2           svm_features_temporales.pkl
# 3           mlp_features_temporales.pkl
# 4          lstm_features_temporales.pkl
# 5           cnn_features_temporales.pkl

# %%
df_test_spec
# Out:
#          Modelo  F1-score  Balanced accuracy  Accuracy  \
# 0  RandomForest  0.937691           0.903883  0.940268
# 1           KNN  0.926737           0.894902  0.928322
# 2           SVM  0.701047           0.626583  0.771562
# 3           MLP  0.878322           0.821865  0.883741
# 4          LSTM  0.561565           0.429824  0.623252
# 5           CNN  0.677783           0.651605  0.677739
#
#                                  Archivo
# 0  randomforest_features_espectrales.pkl
# 1           knn_features_espectrales.pkl
# 2           svm_features_espectrales.pkl
# 3           mlp_features_espectrales.pkl
# 4          lstm_features_espectrales.pkl
# 5           cnn_features_espectrales.pkl
